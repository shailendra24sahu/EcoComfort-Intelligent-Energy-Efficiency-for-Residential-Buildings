# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("energy.csv")

# %%
df.columns
# Out:
# Index(['relative compactness', 'surface area', 'wall area', 'roof area',
#        'overall height', 'orientation', 'glazing area',
#        'glazing area distribution', 'heating load (HL)', 'cooling load (CL)'],
#       dtype='object')

# %%
dict(zip(df.dtypes.index,df.dtypes.values))
# Out:
# {'relative compactness': dtype('float64'),
#  'surface area': dtype('float64'),
#  'wall area': dtype('float64'),
#  'roof area': dtype('float64'),
#  'overall height': dtype('float64'),
#  'orientation': dtype('int64'),
#  'glazing area': dtype('float64'),
#  'glazing area distribution': dtype('int64'),
#  'heating load (HL)': dtype('float64'),
#  'cooling load (CL)': dtype('float64')}

# %%
df
# Out:
#      relative compactness  surface area  wall area  roof area  overall height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
x = df.iloc[:,:-2]
y = df.iloc[:,-2:]

# %%
x
# Out:
#      relative compactness  surface area  wall area  roof area  overall height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
y
# Out:
#      heating load (HL)  cooling load (CL)
# 0                15.55              21.33
# 1                15.55              21.33
# 2                15.55              21.33
# 3                15.55              21.33
# 4                20.84              28.28
# ..                 ...                ...
# 763              17.88              21.40
# 764              16.54              16.88
# 765              16.44              17.11
# 766              16.48              16.61
# 767              16.64              16.03
#
# [768 rows x 2 columns]

# %%
x['label1'] = y.iloc[:,[0]]
x['label2'] = y.iloc[:,[1]]

# %%
x
# Out:
#      relative compactness  surface area  wall area  roof area  overall height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'e:\\Learnings\\iNeuron\\Internship\\EcoComfort-Intelligent-Energy-Efficiency-for-Residential-Buildings\\EDA'

# %%
dir = 'e:\\Learnings\\iNeuron\\Internship\\EcoComfort-Intelligent-Energy-Efficiency-for-Residential-Buildings'

# %%
model_path = os.path.join(dir,'models','RandomForestRegressor0','RandomForestRegressor0.sav')

# %%
model_path
# Out:
# 'e:\\Learnings\\iNeuron\\Internship\\EcoComfort-Intelligent-Energy-Efficiency-for-Residential-Buildings\\models\\RandomForestRegressor0\\RandomForestRegressor0.sav'

# %%
import joblib
model = joblib.load(model_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3424\2374966880.py in <module>
#       1 import joblib
# ----> 2 model = joblib.load(model_path)
#
# e:\Learnings\iNeuron\Internship\EcoComfort-Intelligent-Energy-Efficiency-for-Residential-Buildings\venv\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     595             obj = _unpickle(fobj)
#     596     else:
# --> 597         with open(filename, 'rb') as f:
#     598             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     599                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'e:\\Learnings\\iNeuron\\Internship\\EcoComfort-Intelligent-Energy-Efficiency-for-Residential-Buildings\\models\\RandomForestRegressor0\\RandomForestRegressor0.sav'

# %%
input = [0.9,563.5,318.5,122.5,7,5,0,0]

# %%
model.predict([input])

# %%
model.predict([[0.9,563.5,318.5,122.5,7,5,0,0]])

# %%
model.predict([[0.9,563.5,318.5,122.5,7,5,0,0]])[0][0]

# %%
import pickle
with open(model_path,'rb') as f:
    model = pickle.load(f)

# %%
model.predict([[0.9,563.5,318.5,122.5,7,5,0,0]])

# %%
pred_data = pd.read_csv('energy_efficiency_05012023_122005.csv')

# %%
model.predict(pred_data.values)

# %%
result = []
for val in (model.predict(pred_data.values)):
                    result.append(val)

# %%
result

# %%
result2 = pd.DataFrame(result,columns=['HL_Prediction','CL_Prediction'])

# %%
result2
